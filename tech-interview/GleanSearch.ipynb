# %% [markdown]
# # Glean Solutions Architerct Bonus Search Coding Exercise

# %% [markdown]
# ## Overview
# We will provide the candidate access to the SE Sandbox as a user-only. Prompt sent to the candidate prior the interview.
#
# This is an exercise where you’ll have a hands-on exercise with Glean. This will cover Glean Indexing APIs. You will be given a week to complete your work from the time you are given this prompt.
#
# The required ask is indexing 50 documents of your choice via Glean Indexing API (https://developers.glean.com). During the interview session, you will present your understanding of the APIs and show you have indexed the documents into the Glean platform by searching for them.

# %% [markdown]
# ## Settings
# * The backend server is support-lab-be.glean.com
# * The datasource name is interviewds and the indexing API Token is:<br>
#     **y1ica8IKPeiKjQBPtu99uVyKpl820DE3B9vw7yq1FIM=**
#
# * You can validate your work with access to Glean (in an incognito browser session), browse to https://app.glean.com with the following:
#   * Credential: alex@glean-sandbox.com
#   * Password: IloveGlean123
#
# * Bonus (not required)
#   * The following API Token, **pt4TsekS0seVXlasjRVDsuFQyhcTDdXhXki0Z8klb4o=** can be used for Client Search API, impress us optionally.

# %%
# Import libraries.
import requests
from tabulate import tabulate
import ipywidgets as widgets
from IPython.display import display

# Reference Glean Developer docs, https://developers.glean.com/client/operation/search/. 
url = "https://support-lab-be.glean.com/rest/api/v1/search"

# Define headers
headers = {
    "Authorization": "Bearer pt4TsekS0seVXlasjRVDsuFQyhcTDdXhXki0Z8klb4o=",
    "Content-Type": "application/json",
    #"X-Scio-ActAs": "alex@glean-lab.com"
}

# Create a text input box for query term. Displays at the bottom of executed cell.
query_input = widgets.Text(
    value='MTB',
    placeholder='Enter your query',
    description='Query:',
    disabled=False
)
display(query_input)

# Search payload. Reference Glean Developer docs, https://developers.glean.com/client/operation/search/.
def perform_search(query):
    payload = {
        "trackingToken": "trackingToken",
        "query": query,
        "pageSize": 10,
        "requestOptions": {
            "facetBucketSize": 1,
            "facetFilters": [
                {
                    "fieldName": "type",
                    "values": [
                        {
                            "value": "article",
                            "relationType": "EQUALS"
                        },
                        {
                            "value": "document",
                            "relationType": "EQUALS"
                        }
                    ]
                }
            ]
        }
    }

    try:
        # Create an empty list to store all the results.
        all_results = []

        # Initialize the next page token to None.
        next_page_token = None

        while True:
            if next_page_token:
                payload['nextPageToken'] = next_page_token

            # Request the search results.
            response = requests.post(url, headers=headers, json=payload)

            # Raise HTTP error for bad responses (4xx and 5xx).
            response.raise_for_status()
            
            # Get response in JSON format.
            data = response.json()
            
            # Combine results.
            results = data.get('results', [])
            all_results.extend(results)
            
            # Is there another page? 
            next_page_token = data.get('nextPageToken')
            if not next_page_token:
                break

        # Create table for search results display.
        table = []

        # Define table headers based on Search request parameters.
        table_headers = ["title", "url", "objectType", "datasource", "documentId", "createTime", "updateTime", "visibility", "documentCategory"] 
        
        for result in all_results:
            document = result.get('document', {})
            metadata = document.get('metadata', {})
            
            row = [
                document.get('title'),
                document.get('url'),
                metadata.get('objectType'),
                document.get('datasource'),
                metadata.get('documentId'),
                metadata.get('createTime'),
                metadata.get('updateTime'),
                metadata.get('visibility'),
                metadata.get('documentCategory')
            ]
            table.append(row)
        
        # Output table.
        print(tabulate(table, headers=table_headers, tablefmt="github"))
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except Exception as err:
        print(f"Other error occurred: {err}")
#
# ---- UI Components ----
#
# # Create a button for search.
search_button = widgets.Button(description="Search")
display(search_button)

def on_search_button_clicked(b):
    perform_search(query_input.value)
search_button.on_click(on_search_button_clicked)
# Out:
# Text(value='MTB', description='Query:', placeholder='Enter your query')
# Button(description='Search', style=ButtonStyle())
# | title                  | url                    | objectType   | datasource   | documentId                               | createTime           | updateTime           | visibility     | documentCategory   |
# |------------------------|------------------------|--------------|--------------|------------------------------------------|----------------------|----------------------|----------------|--------------------|
# | Mounatin Bike Story 50 | https://app.glean.com/ | Document     | interviewds  | CUSTOM_INTERVIEWDS_document_mtb-story-50 | 1970-01-01T00:00:00Z | 1970-01-01T00:00:00Z | PUBLIC_VISIBLE | KNOWLEDGE_HUB      |
# | title                                                                                                                                  | url                                                                                                                                                      | objectType   | datasource               | documentId                                   | createTime           | updateTime           | visibility     | documentCategory   |
# |----------------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------|--------------|--------------------------|----------------------------------------------|----------------------|----------------------|----------------|--------------------|
# | Mounatin Bike Story 50                                                                                                                 | https://app.glean.com/                                                                                                                                   | Document     | interviewds              | CUSTOM_INTERVIEWDS_document_mtb-story-50     | 1970-01-01T00:00:00Z | 1970-01-01T00:00:00Z | PUBLIC_VISIBLE | KNOWLEDGE_HUB      |
# | Area - rankings - The World Factbook                                                                                                   | https://www.cia.gov/the-world-factbook/field/area-rankings                                                                                               | Document     | webzzpnfvqworldfactbook  | webzzpnfvqworldfactbook_4900528755956131912  | 1970-01-01T00:00:00Z | 2024-08-15T07:16:32Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Mountain Mike's Pizza                                                                                                                  | https://en.wikipedia.org/wiki/Mountain_Mike's_Pizza                                                                                                      | article      | wikipediatest            | CUSTOM_WIKIPEDIATEST_Article_25317039        | 1970-01-01T00:00:00Z | 1970-01-01T00:00:00Z | PUBLIC_VISIBLE | KNOWLEDGE_HUB      |
# | Mario Kart 8 Deluxe – Booster Course Pass Wave 3 Brings Merry Mountain Mayhem with Eight Additional Courses on 8th December - Nintendo | https://www.nintendo.com/au/news-and-articles/mario-kart-8-deluxe-booster-course-pass-wave-3-brings-merry-mountain-mayhem-with-eight-additional-courses/ | Document     | webt5ajprunintendo       | webt5ajprunintendo_8522434651069602729       | 1970-01-01T00:00:00Z | 1970-01-01T00:00:00Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Eastern Mountain Sports                                                                                                                | https://en.wikipedia.org/wiki/Eastern_Mountain_Sports                                                                                                    | article      | wikipediatest            | CUSTOM_WIKIPEDIATEST_Article_1234820         | 1970-01-01T00:00:00Z | 1970-01-01T00:00:00Z | PUBLIC_VISIBLE | KNOWLEDGE_HUB      |
# | Terrain - The World Factbook                                                                                                           | https://www.cia.gov/the-world-factbook/field/terrain                                                                                                     | Document     | webzzpnfvqworldfactbook  | webzzpnfvqworldfactbook_6701831444411836946  | 1970-01-01T00:00:00Z | 2024-08-15T07:16:32Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Display Content Printable Version                                                                                                      | https://www.digitalhistory.uh.edu/disp_textbook_print.cfm?smtid=2&psid=3254                                                                              | Document     | webx5qdsfedigitalhistory | webx5qdsfedigitalhistory_2370725754134591147 | 1970-01-01T00:00:00Z | 1970-01-01T00:00:00Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Bathymetry - The World Factbook                                                                                                        | https://www.cia.gov/the-world-factbook/field/bathymetry                                                                                                  | Document     | webzzpnfvqworldfactbook  | webzzpnfvqworldfactbook_9160045511496116775  | 1970-01-01T00:00:00Z | 2024-08-15T07:16:32Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Geography - note - The World Factbook                                                                                                  | https://www.cia.gov/the-world-factbook/field/geography-note                                                                                              | Document     | webzzpnfvqworldfactbook  | webzzpnfvqworldfactbook_4687958421880881350  | 1970-01-01T00:00:00Z | 2024-08-15T07:16:32Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Population distribution - The World Factbook                                                                                           | https://www.cia.gov/the-world-factbook/field/population-distribution                                                                                     | Document     | webzzpnfvqworldfactbook  | webzzpnfvqworldfactbook_6608700989670625470  | 1970-01-01T00:00:00Z | 2024-08-15T07:16:32Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | title                                                             | url                                                                                                  | objectType   | datasource                             | documentId                                                  | createTime           | updateTime           | visibility     | documentCategory   |
# |-------------------------------------------------------------------|------------------------------------------------------------------------------------------------------|--------------|----------------------------------------|-------------------------------------------------------------|----------------------|----------------------|----------------|--------------------|
# | N°1 DE CHANEL – Discover in Boutiques | CHANEL | CHANEL           | https://www.chanel.com/us/skincare/n1-de-chanel/boutiques/                                           | Document     | webjaulr8cchanel                       | webjaulr8cchanel_13310709599373330123                       | 1970-01-01T00:00:00Z | 1970-01-01T00:00:00Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Mexico - The World Factbook                                       | https://www.cia.gov/the-world-factbook/countries/mexico                                              | Document     | webzzpnfvqworldfactbook                | webzzpnfvqworldfactbook_3178418651375375347                 | 1970-01-01T00:00:00Z | 2024-08-15T07:16:32Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Diplomatic representation in the US - The World Factbook          | https://www.cia.gov/the-world-factbook/field/diplomatic-representation-in-the-us                     | Document     | webzzpnfvqworldfactbook                | webzzpnfvqworldfactbook_2456649659738766795                 | 1970-01-01T00:00:00Z | 2024-08-15T07:16:32Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Airports - The World Factbook                                     | https://www.cia.gov/the-world-factbook/about/archives/2023/field/airports                            | Document     | webzzpnfvqworldfactbook                | webzzpnfvqworldfactbook_7560765770237242998                 | 1970-01-01T00:00:00Z | 2023-12-28T13:19:12Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | CHANEL Stores in the United States - Fragrance & Beauty | CHANEL  | https://www.chanel.com/us/fragrance-beaute-boutiques/                                                | Document     | webjaulr8cchanel                       | webjaulr8cchanel_15963554843451874094                       | 1970-01-01T00:00:00Z | 1970-01-01T00:00:00Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Diplomatic representation in the US - 2022 World Factbook Archive | https://www.cia.gov/the-world-factbook/about/archives/2022/field/diplomatic-representation-in-the-us | Document     | webzzpnfvqworldfactbook                | webzzpnfvqworldfactbook_16306641562739631745                | 1970-01-01T00:00:00Z | 2023-08-18T17:57:29Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Mexico - 2022 World Factbook Archive                              | https://www.cia.gov/the-world-factbook/about/archives/2022/countries/mexico                          | Document     | webzzpnfvqworldfactbook                | webzzpnfvqworldfactbook_2100011728302565093                 | 1970-01-01T00:00:00Z | 2023-08-18T17:57:29Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Airports - 2022 World Factbook Archive                            | https://www.cia.gov/the-world-factbook/about/archives/2022/field/airports                            | Document     | webzzpnfvqworldfactbook                | webzzpnfvqworldfactbook_13440873269422399567                | 1970-01-01T00:00:00Z | 2023-08-18T17:57:29Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Ports and terminals - The World Factbook                          | https://www.cia.gov/the-world-factbook/about/archives/2023/field/ports-and-terminals                 | Document     | webzzpnfvqworldfactbook                | webzzpnfvqworldfactbook_9906122265281015637                 | 1970-01-01T00:00:00Z | 2023-12-28T13:19:12Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
# | Fact Sheets | ConocoPhillips                                      | https://www.conocophillips.com/company-reports-resources/fact-sheets/                                | Document     | webpjuxybdconocophillipswebsitepartial | webpjuxybdconocophillipswebsitepartial_18032739852382108702 | 1970-01-01T00:00:00Z | 1970-01-01T00:00:00Z | PUBLIC_VISIBLE | PUBLISHED_CONTENT  |
